# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings # ignore warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Features
#
#     product_id - Product ID
#     product_name - Name of the Product
#     category - Category of the Product
#     discounted_price - Discounted Price of the Product
#     actual_price - Actual Price of the Product
#     discount_percentage - Percentage of Discount for the Product
#     rating - Rating of the Product
#     rating_count - Number of people who voted for the Amazon rating
#     about_product - Description about the Product
#     user_id - ID of the user who wrote review for the Product
#     user_name - Name of the user who wrote review for the Product
#     review_id - ID of the user review
#     review_title - Short review
#     review_content - Long review
#     img_link - Image Link of the Product
#     product_link - Official Website Link of the Product

# %% [markdown]
# # **Data Processing**

# %%
df = pd.read_csv("amazon.csv")

# %%
df.head(5)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
# 3         ₹699                 53%    4.2       94,363
# 4         ₹399                 61%    4.2       16,905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4  R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
# 3  Good product,long wire,Charges good,Nice,I bou...
# 4  Bought this instead of original apple, does th...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
# 3  https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...

# %%
df.shape
# Out:
# (1465, 16)

# %%
df.tail()
# Out:
#       product_id                                       product_name  \
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 1460  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...             ₹379
# 1461  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,280
# 1462  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...           ₹2,219
# 1463  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...           ₹1,399
# 1464  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,863
#
#      actual_price discount_percentage rating rating_count  \
# 1460         ₹919                 59%      4        1,090
# 1461       ₹3,045                 25%    4.1        4,118
# 1462       ₹3,080                 28%    3.6          468
# 1463       ₹1,890                 26%      4        8,031
# 1464       ₹3,690                 22%    4.3        6,987
#
#                                           about_product  \
# 1460  SUPREME QUALITY 90 GRAM 3 LAYER THIK PP SPUN F...
# 1461                       230 Volts, 400 watts, 1 Year
# 1462  International design and styling|Two heat sett...
# 1463  Fan sweep area: 230 MM ; Noise level: (40 - 45...
# 1464  Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
#
#                                                 user_id  \
# 1460  AHITFY6AHALOFOHOZEOC6XBP4FEA,AFRABBODZJZQB6Z4U...
# 1461  AFG5FM3NEMOL6BNFRV2NK5FNJCHQ,AGEINTRN6Z563RMLH...
# 1462  AGVPWCMAHYQWJOQKMUJN4DW3KM5Q,AF4Q3E66MY4SR7YQZ...
# 1463  AF2JQCLSCY3QJATWUNNHUSVUPNQQ,AFDMLUXC5LS5RXDJS...
# 1464  AFGW5PT3R6ZAVQR4Y5MWVAKBZAYA,AG7QNJ2SCS5VS5VYY...
#
#                                               user_name  \
# 1460  Prabha ds,Raghuram bk,Real Deal,Amazon Custome...
# 1461  Manu Bhai,Naveenpittu,Evatira Sangma,JAGANNADH...
# 1462  Nehal Desai,Danish Parwez,Amazon Customer,Amaz...
# 1463  Shubham Dubey,E.GURUBARAN,Mayank S.,eusuf khan...
# 1464  Rajib,Ajay B,Vikas Kahol,PARDEEP,Anindya Prama...
#
#                                               review_id  \
# 1460  R3G3XFHPBFF0E8,R3C0BZCD32EIGW,R2EBVBCN9QPD9R,R...
# 1461  R3DDL2UPKQ2CK9,R2SYYU1OATVIU5,R1VM993161IYRW,R...
# 1462  R1TLRJVW4STY5I,R2O455KRN493R1,R3Q5MVGBRIAS2G,R...
# 1463  R39Q2Y79MM9SWK,R3079BG1NIH6MB,R29A31ZELTZNJM,R...
# 1464  R20RBRZ0WEUJT9,ROKIFK9R2ISSE,R30EEG2FNJSN5I,R2...
#
#                                            review_title  \
# 1460  Received the product without spanner,Excellent...
# 1461  ok,everything was good couldn't return bcoz I ...
# 1462  very good,Work but front melt after 2 month,Go...
# 1463  Fan Speed is slow,Good quality,Good product,go...
# 1464  Works perfect,Ok good product,Nice Product. Re...
#
#                                          review_content  \
# 1460  I received product without spanner,Excellent p...
# 1461  ok,got everything as mentioned but the measuri...
# 1462  plastic but cool body ,u have to find sturdy s...
# 1463  I have installed this in my kitchen working fi...
# 1464  It does it job perfectly..only issue is temp c...
#
#                                                img_link  \
# 1460  https://m.media-amazon.com/images/I/41fDdRtjfx...
# 1461  https://m.media-amazon.com/images/I/41gzDxk4+k...
# 1462  https://m.media-amazon.com/images/W/WEBP_40237...
# 1463  https://m.media-amazon.com/images/W/WEBP_40237...
# 1464  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                            product_link
# 1460  https://www.amazon.in/Noir-Aqua-Spanner-Purifi...
# 1461  https://www.amazon.in/Prestige-Delight-PRWO-1-...
# 1462  https://www.amazon.in/Bajaj-RX-10-2000-Watt-Co...
# 1463  https://www.amazon.in/Havells-Ventilair-230mm-...
# 1464  https://www.amazon.in/Borosil-Jumbo-1000-Watt-...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
#  15  product_link         1465 non-null   object
# dtypes: object(16)
# memory usage: 183.3+ KB

# %% [markdown]
# All variables are of object data type and thus strings. For better use there is need to convert them to numerical to be used later in complex calculations and models.

# %%
df.describe()
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B07JW9H4J1  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# top            ₹999                 50%    4.1        9,378
# freq            120                  56    244            9
#
#                                             about_product  \
# count                                                1465
# unique                                               1293
# top     [CHARGE & SYNC FUNCTION]- This cable comes wit...
# freq                                                    6
#
#                                                   user_id  \
# count                                                1465
# unique                                               1194
# top     AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA,AE55KTFVNXYFD5FPY...
# freq                                                   10
#
#                                                 user_name  \
# count                                                1465
# unique                                               1194
# top     $@|\|TO$|-|,Sethu madhav,Akash Thakur,Burger P...
# freq                                                   10
#
#                                                 review_id  \
# count                                                1465
# unique                                               1194
# top     R3F4T5TRYPTMIG,R3DQIEC603E7AY,R1O4Z15FD40PV5,R...
# freq                                                   10
#
#                                              review_title  \
# count                                                1465
# unique                                               1194
# top     Worked on iPhone 7 and didn’t work on XR,Good ...
# freq                                                   10
#
#                                            review_content  \
# count                                                1465
# unique                                               1212
# top     I am not big on camera usage, personally. I wa...
# freq                                                    8
#
#                                                  img_link  \
# count                                                1465
# unique                                               1412
# top     https://m.media-amazon.com/images/I/413sCRKobN...
# freq                                                    3
#
#                                              product_link
# count                                                1465
# unique                                               1465
# top     https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# freq                                                    1

# %%
# Check for missing values
print(df.isnull().sum()) # 2 missing values on rating_count
df[df.rating_count.isnull()] # print rows with missing fields
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64
#      product_id                                       product_name  \
# 282  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                               category discounted_price  \
# 282  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 324  Computers&Accessories|Accessories&Peripherals|...             ₹249
#
#     actual_price discount_percentage rating rating_count  \
# 282         ₹999                 80%    3.0          NaN
# 324         ₹999                 75%    5.0          NaN
#
#                                          about_product  \
# 282  USB C to C Cable: This cable has type C connec...
# 324  💎[The Fastest Charge] - This iPhone USB C cabl...
#
#                           user_id    user_name      review_id  \
# 282  AE7CFHY23VAJT2FI4NZKKP6GS2UQ       Pranav   RUB7U91HVZ30
# 324  AGJC5O5H5BBXWUV7WRIEIOOR3TVQ  Abdul Gafur  RQXD5SAMMPC6L
#
#                                      review_title  \
# 282  The cable works but is not 65W as advertised
# 324                               Awesome Product
#
#                                         review_content  \
# 282  I have a pd supported car charger and I bought...
# 324  Quick delivery.Awesome ProductPacking was good...
#
#                                               img_link  \
# 282  https://m.media-amazon.com/images/W/WEBP_40237...
# 324  https://m.media-amazon.com/images/I/31-q0xhaTA...
#
#                                           product_link
# 282  https://www.amazon.in/Amazon-Brand-Charging-Su...
# 324  https://www.amazon.in/REDTECH-Lightning-Certif...

# %%
# Remove rows with missing values in the rating_count column
# They are only 2, they wont affect the datase
df.dropna(subset=['rating_count'], inplace=True)
print(df.isnull().sum())
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
#format numerial columns, remove symbols from rows
df['discounted_price'] = df['discounted_price'].astype(str).str.replace('₹', '').str.replace(',', '').astype(float)
df['actual_price'] = df['actual_price'].astype(str).str.replace('₹', '').str.replace(',', '').astype(float)
df['discount_percentage'] = df['discount_percentage'].astype(str).str.replace('%','').astype(float)/100

# %%
# The rating column has a value with an incorrect character, so we will exclude
# the row to obtain a clean dataset.
count = df['rating'].str.contains('\|').sum()
print(f"Total rows containing '|' on 'rating': {count}")
df = df[df['rating'].apply(lambda x: '|' not in str(x))]
count = df['rating'].str.contains('\|').sum()
print(f"Total rows containing '|' on 'rating': {count}")
# Out:
# Total rows containing '|' on 'rating': 1
# Total rows containing '|' on 'rating': 0

# %%
df['rating'] = df['rating'].astype(str).str.replace(',', '').astype(float)
df['rating_count'] = df['rating_count'].astype(str).str.replace(',', '').astype(float)

# %%
# Function to check for special characters
def has_special_chars(s):
    return any(char.isdigit() or char.isalpha() or char.isspace() for char in s)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1462 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1462 non-null   object
#  1   product_name         1462 non-null   object
#  2   category             1462 non-null   object
#  3   discounted_price     1462 non-null   float64
#  4   actual_price         1462 non-null   float64
#  5   discount_percentage  1462 non-null   float64
#  6   rating               1462 non-null   float64
#  7   rating_count         1462 non-null   float64
#  8   about_product        1462 non-null   object
#  9   user_id              1462 non-null   object
#  10  user_name            1462 non-null   object
#  11  review_id            1462 non-null   object
#  12  review_title         1462 non-null   object
#  13  review_content       1462 non-null   object
#  14  img_link             1462 non-null   object
#  15  product_link         1462 non-null   object
# dtypes: float64(5), object(11)
# memory usage: 194.2+ KB

# %%
df.dtypes
# Out:
# product_id              object
# product_name            object
# category                object
# discounted_price       float64
# actual_price           float64
# discount_percentage    float64
# rating                 float64
# rating_count           float64
# about_product           object
# user_id                 object
# user_name               object
# review_id               object
# review_title            object
# review_content          object
# img_link                object
# product_link            object
# dtype: object

# %%
# Creating the column "rating_weighted"
df['rating_weighted'] = df['rating'] * df['rating_count']

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                 0.64     4.2       24269.0
# 1         349.0                 0.43     4.0       43994.0
# 2        1899.0                 0.90     3.9        7928.0
# 3         699.0                 0.53     4.2       94363.0
# 4         399.0                 0.61     4.2       16905.0
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4  R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
# 3  Good product,long wire,Charges good,Nice,I bou...
# 4  Bought this instead of original apple, does th...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
# 3  https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link  rating_weighted
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...         101929.8
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...         175976.0
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...          30919.2
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...         396324.6
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...          71001.0

# %% [markdown]
# The creation of "rating_weighted" benefits us because it can be created as a way of considering not only the average rating, but also the number of people who rated the product. This column weighs the average rating by the number of ratings, giving more weight to ratings with a large number of raters. This can help identify products with high customer satisfaction and many positive ratings compared to products with high average ratings but few raters.

# %% [markdown]
# Extracting and breaking down product categories into sub_category and main_category extracts a clearer view and classification of products among categories. This helps drive informed decision making as well as exploratory analysis and visualizations.

# %%
df['sub_category'] = df['category'].astype(str).str.split('|').str[-1]
df['main_category'] = df['category'].astype(str).str.split('|').str[0]

# %%
df.T
# Out:
#                                                                   0     \
# product_id                                                  B07JW9H4J1
# product_name         Wayona Nylon Braided USB to Lightning Fast Cha...
# category             Computers&Accessories|Accessories&Peripherals|...
# discounted_price                                                 399.0
# actual_price                                                    1099.0
# discount_percentage                                               0.64
# rating                                                             4.2
# rating_count                                                   24269.0
# about_product        High Compatibility : Compatible With iPhone 12...
# user_id              AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# user_name            Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# review_id            R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# review_title         Satisfied,Charging is really fast,Value for mo...
# review_content       Looks durable Charging is fine tooNo complains...
# img_link             https://m.media-amazon.com/images/W/WEBP_40237...
# product_link         https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# rating_weighted                                               101929.8
# sub_category                                                 USBCables
# main_category                                    Computers&Accessories
#
#                                                                   1     \
# product_id                                                  B098NS6PVG
# product_name         Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# category             Computers&Accessories|Accessories&Peripherals|...
# discounted_price                                                 199.0
# actual_price                                                     349.0
# discount_percentage                                               0.43
# rating                                                             4.0
# rating_count                                                   43994.0
# about_product        Compatible with all Type C enabled devices, be...
# user_id              AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# user_name            ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# review_id            RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# review_title         A Good Braided Cable for Your Type C Device,Go...
# review_content       I ordered this cable to connect my phone to An...
# img_link             https://m.media-amazon.com/images/W/WEBP_40237...
# product_link         https://www.amazon.in/Ambrane-Unbreakable-Char...
# rating_weighted                                               175976.0
# sub_category                                                 USBCables
# main_category                                    Computers&Accessories
#
#                                                                   2     \
# product_id                                                  B096MSW6CT
# product_name         Sounce Fast Phone Charging Cable & Data Sync U...
# category             Computers&Accessories|Accessories&Peripherals|...
# discounted_price                                                 199.0
# actual_price                                                    1899.0
# discount_percentage                                                0.9
# rating                                                             3.9
# rating_count                                                    7928.0
# about_product        【 Fast Charger& Data Sync】-With built-in safet...
# user_id              AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# user_name            Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# review_id            R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# review_title         Good speed for earlier versions,Good Product,W...
# review_content       Not quite durable and sturdy,https://m.media-a...
# img_link             https://m.media-amazon.com/images/W/WEBP_40237...
# product_link         https://www.amazon.in/Sounce-iPhone-Charging-C...
# rating_weighted                                                30919.2
# sub_category                                                 USBCables
# main_category                                    Computers&Accessories
#
#                                                                   3     \
# product_id                                                  B08HDJ86NZ
# product_name         boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# category             Computers&Accessories|Accessories&Peripherals|...
# discounted_price                                                 329.0
# actual_price                                                     699.0
# discount_percentage                                               0.53
# rating                                                             4.2
# rating_count                                                   94363.0
# about_product        The boAt Deuce USB 300 2 in 1 cable is compati...
# user_id              AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# user_name            Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# review_id            R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# review_title         Good product,Good one,Nice,Really nice product...
# review_content       Good product,long wire,Charges good,Nice,I bou...
# img_link             https://m.media-amazon.com/images/I/41V5FtEWPk...
# product_link         https://www.amazon.in/Deuce-300-Resistant-Tang...
# rating_weighted                                               396324.6
# sub_category                                                 USBCables
# main_category                                    Computers&Accessories
#
#                                                                   4     \
# product_id                                                  B08CF3B7N1
# product_name         Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# category             Computers&Accessories|Accessories&Peripherals|...
# discounted_price                                                 154.0
# actual_price                                                     399.0
# discount_percentage                                               0.61
# rating                                                             4.2
# rating_count                                                   16905.0
# about_product        [CHARGE & SYNC FUNCTION]- This cable comes wit...
# user_id              AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
# user_name            rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
# review_id            R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
# review_title         As good as original,Decent,Good one for second...
# review_content       Bought this instead of original apple, does th...
# img_link             https://m.media-amazon.com/images/W/WEBP_40237...
# product_link         https://www.amazon.in/Portronics-Konnect-POR-1...
# rating_weighted                                                71001.0
# sub_category                                                 USBCables
# main_category                                    Computers&Accessories
#
#                                                                   5     \
# product_id                                                  B08Y1TFSP6
# product_name         pTron Solero TB301 3A Type-C Data and Fast Cha...
# category             Computers&Accessories|Accessories&Peripherals|...
# discounted_price                                                 149.0
# actual_price                                                    1000.0
# discount_percentage                                               0.85
# rating                                                             3.9
# rating_count                                                   24871.0
# about_product        Fast Charging & Data Sync: Solero TB301 Type-C...
# user_id              AEQ2YMXSZWEOHK2EHTNLOS56YTZQ,AGRVINWECNY7323CW...
# user_name            Jayesh,Rajesh k.,Soopy,amazon customer,Aman,Sh...
# review_id            R7S8ANNSDPR40,R3CLZFLHVJU26P,RFF7U7MPQFUGR,R1M...
# review_title         It's pretty good,Average quality,very good and...
# review_content       It's a good product.,Like,Very good item stron...
# img_link             https://m.media-amazon.com/images/I/31wOPjcSxl...
# product_link         https://www.amazon.in/Solero-TB301-Charging-48...
# rating_weighted                                                96996.9
# sub_category                                                 USBCables
# main_category                                    Computers&Accessories
#
#                                                                   6     \
# product_id                                                  B08WRWPM22
# product_name         boAt Micro USB 55 Tangle-free, Sturdy Micro US...
# category             Computers&Accessories|Accessories&Peripherals|...
# discounted_price                                                176.63
# actual_price                                                     499.0
# discount_percentage                                               0.65
# rating                                                             4.1
# rating_count                                                   15188.0
# about_product        It Ensures High Speed Transmission And Chargin...
# user_id              AG7C6DAADCTRQJG2BRS3RIKDT52Q,AFU7BOMPVJ7Q3TTA4...
# user_name            Vivek kumar,Amazon Customer,SARTHAK,Chiranjeev...
# review_id            R8E73K2KWJRDS,RSD0JTIIWQQL8,R64CRSTE9SLW1,R2FR...
# review_title         Long durable.,good,Does not charge Lenovo m8 t...
# review_content       Build quality is good and it is comes with 2 y...
# img_link             https://m.media-amazon.com/images/W/WEBP_40237...
# product_link         https://www.amazon.in/boAt-Micro-USB-Tangle-Fr...
# rating_weighted                                                62270.8
# sub_category                                                 USBCables
# main_category                                    Computers&Accessories
#
#                                                                   7     \
# product_id                                                  B08DDRGWTJ
# product_name                    MI Usb Type-C Cable Smartphone (Black)
# category             Computers&Accessories|Accessories&Peripherals|...
# discounted_price                                                 229.0
# actual_price                                                     299.0
# discount_percentage                                               0.23
# rating                                                             4.3
# rating_count                                                   30411.0
# about_product        1m long Type-C USB Cable|Sturdy and Durable. W...
# user_id              AHW6E5LQ2BDYOIVLAJGDH45J5V5Q,AF74RSGCHPZITVFSZ...
# user_name            Pavan A H,Jayesh bagad,Shridhar,rajendran,karu...
# review_id            R2X090D1YHACKR,R32ZCIH9AFNJ60,R3N57EVVG0EHAF,R...
# review_title         Worth for money - suitable for Android auto,Go...
# review_content       Worth for money - suitable for Android auto......
# img_link             https://m.media-amazon.com/images/I/31XO-wfGGG...
# product_link         https://www.amazon.in/MI-MTCY001IN-USB-Type-C-...
# rating_weighted                                               130767.3
# sub_category                                                 USBCables
# main_category                                    Computers&Accessories
#
#                                                                   8     \
# product_id                                                  B008IFXQFU
# product_name         TP-Link USB WiFi Adapter for PC(TL-WN725N), N1...
# category             Computers&Accessories|NetworkingDevices|Networ...
# discounted_price                                                 499.0
# actual_price                                                     999.0
# discount_percentage                                                0.5
# rating                                                             4.2
# rating_count                                                  179691.0
# about_product        USB WiFi Adapter —— Speedy wireless transmissi...
# user_id              AGV3IEFANZCKECFGUM42MRH5FNOA,AEBO7NWCNXKT4AESA...
# user_name            Azhar JuMan,Anirudh Sood,Hari Krishnan PS,Akas...
# review_id            R1LW6NWSVTVZ2H,R3VR5WFKUS15C5,R2F6GC79OYWUKQ,R...
# review_title         Works on linux for me. Get the model with ante...
# review_content       I use this to connect an old PC to internet. I...
# img_link             https://m.media-amazon.com/images/W/WEBP_40237...
# product_link         https://www.amazon.in/TP-Link-TL-WN725N-150Mbp...
# rating_weighted                                               754702.2
# sub_category                                       WirelessUSBAdapters
# main_category                                    Computers&Accessories
#
#                                                                   9     ...  \
# product_id                                                  B082LZGK39  ...
# product_name         Ambrane Unbreakable 60W / 3A Fast Charging 1.5...  ...
# category             Computers&Accessories|Accessories&Peripherals|...  ...
# discounted_price                                                 199.0  ...
# actual_price                                                     299.0  ...
# discount_percentage                                               0.33  ...
# rating                                                             4.0  ...
# rating_count                                                   43994.0  ...
# about_product        Universal Compatibility – It is compatible wit...  ...
# user_id              AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...  ...
# user_name            ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...  ...
# review_id            RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...  ...
# review_title         A Good Braided Cable for Your Type C Device,Go...  ...
# review_content       I ordered this cable to connect my phone to An...  ...
# img_link             https://m.media-amazon.com/images/W/WEBP_40237...  ...
# product_link         https://www.amazon.in/Ambrane-Unbreakable-Char...  ...
# rating_weighted                                               175976.0  ...
# sub_category                                                 USBCables  ...
# main_category                                    Computers&Accessories  ...
#
#                                                                   1455  \
# product_id                                                  B00GHL8VP2
# product_name         USHA 1212 PTC with Adjustable Thermostat Fan H...
# category             Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...
# discounted_price                                               3487.77
# actual_price                                                    4990.0
# discount_percentage                                                0.3
# rating                                                             4.1
# rating_count                                                    1127.0
# about_product        Meant for Spot Heating|Room Size: Upto 15 sq f...
# user_id              AECFYIUCHSZXDLACTYPEUSM5DIKA,AF546S43YKYCJWRD7...
# user_name            Manoj Kumar,Arun Thottakathu Prasannakumar,son...
# review_id            R1T19FVDX8Z7T2,R1E1AMYN17K7HJ,R20AXB80IQO0DK,R...
# review_title         I like this product,Simple easy to use, but no...
# review_content       ,Cost effective. This is good for heating your...
# img_link             https://m.media-amazon.com/images/W/WEBP_40237...
# product_link         https://www.amazon.in/Usha-1212-PTC-Adjustable...
# rating_weighted                                                 4620.7
# sub_category                                           ElectricHeaters
# main_category                                             Home&Kitchen
#
#                                                                   1456  \
# product_id                                                  B0B9JZW1SQ
# product_name         4 in 1 Handheld Electric Vegetable Cutter Set,...
# category             Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# discounted_price                                                 498.0
# actual_price                                                    1200.0
# discount_percentage                                               0.59
# rating                                                             3.2
# rating_count                                                     113.0
# about_product        { 4 in 1 multi-function Electric Vegetable Cut...
# user_id              AFCTMQKPVJI6Y2JPIGDKRKIAV43A,AF6XUHN32GSFA7LFG...
# user_name            Ashish,Kavita J.,Sundar,Tessy S.,saurabh manro...
# review_id            R3N2A5DV7IPG6R,RXX6FP17PFNBS,R1JENN8Y0UV8G,RXP...
# review_title         Cutter speed and power is very low,Nt happy wi...
# review_content       ,It's nt wrkng evn aftr 4 hours of charging,Th...
# img_link             https://m.media-amazon.com/images/W/WEBP_40237...
# product_link         https://www.amazon.in/Handheld-Electric-Vegeta...
# rating_weighted                                                  361.6
# sub_category                               MiniFoodProcessors&Choppers
# main_category                                             Home&Kitchen
#
#                                                                   1457  \
# product_id                                                  B00TI8E7BI
# product_name         Philips HD9306/06 1.5-Litre Electric Kettle (M...
# category             Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# discounted_price                                                2695.0
# actual_price                                                    2695.0
# discount_percentage                                                0.0
# rating                                                             4.4
# rating_count                                                    2518.0
# about_product        Food grade stainless steel, Frequency: 50 Hz. ...
# user_id              AHYXOMUJUKZHBWHP43ZAB265EDGA,AG4C27NTZZ7HTG6W3...
# user_name            AmazonCust,DD_Zen,Amazon Customer,VINISH THOMA...
# review_id            R252H4TFMWK9L7,R3SAFGRVGD7GTV,R1FVCFYT4SGY76,R...
# review_title         3,Sturdy and Works Flawlessly,Excellent 👍,Real...
# review_content       Cord is small and sound while heating,Well bui...
# img_link             https://m.media-amazon.com/images/I/41JyZuDzDg...
# product_link         https://www.amazon.in/Philips-HD9306-06-1-5-Li...
# rating_weighted                                                11079.2
# sub_category                                           ElectricKettles
# main_category                                             Home&Kitchen
#
#                                                                   1458  \
# product_id                                                  B07J9KXQCC
# product_name         Libra Room Heater for Home, Room Heaters Home ...
# category             Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...
# discounted_price                                                 949.0
# actual_price                                                    2299.0
# discount_percentage                                               0.59
# rating                                                             3.6
# rating_count                                                     550.0
# about_product        Libra room heater for home has cool, warm or h...
# user_id              AE5FZ5B3EEES45Q26PNUBTJ5DRYA,AGL2B432J2VDHOSUW...
# user_name            gitesh jaiswal,Divyansh,Dr Paras,Amazon Custom...
# review_id            R363CESXF8MX1J,RPFBIUJQY7U8J,R1RANSDWMZLOFX,R2...
# review_title         Product functioning ok but price is quite high...
# review_content       For the product like room heater package shoul...
# img_link             https://m.media-amazon.com/images/I/51GEjZAmNR...
# product_link         https://www.amazon.in/LIBRA-Portable-Heater-Ad...
# rating_weighted                                                 1980.0
# sub_category                                           ElectricHeaters
# main_category                                             Home&Kitchen
#
#                                                                   1459  \
# product_id                                                  B0B3JSWG81
# product_name         NGI Store 2 Pieces Pet Hair Removers for Your ...
# category             Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...
# discounted_price                                                 199.0
# actual_price                                                     999.0
# discount_percentage                                                0.8
# rating                                                             3.1
# rating_count                                                       2.0
# about_product        Versatile, Protects Your Clothes: MoveCatcher ...
# user_id                                   AFPKVN5KLHB4MHSYDS25Q5MIWWKQ
# user_name                                                    Kunal Sen
# review_id                                               R18OKMWGX8SA0L
# review_title                                                   Useless
# review_content       Does not work as advertised at all. The pieces...
# img_link             https://m.media-amazon.com/images/W/WEBP_40237...
# product_link         https://www.amazon.in/Hair-Removers-Laundry-Re...
# rating_weighted                                                    6.2
# sub_category                                               LintShavers
# main_category                                             Home&Kitchen
#
#                                                                   1460  \
# product_id                                                  B08L7J3T31
# product_name         Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# category             Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...
# discounted_price                                                 379.0
# actual_price                                                     919.0
# discount_percentage                                               0.59
# rating                                                             4.0
# rating_count                                                    1090.0
# about_product        SUPREME QUALITY 90 GRAM 3 LAYER THIK PP SPUN F...
# user_id              AHITFY6AHALOFOHOZEOC6XBP4FEA,AFRABBODZJZQB6Z4U...
# user_name            Prabha ds,Raghuram bk,Real Deal,Amazon Custome...
# review_id            R3G3XFHPBFF0E8,R3C0BZCD32EIGW,R2EBVBCN9QPD9R,R...
# review_title         Received the product without spanner,Excellent...
# review_content       I received product without spanner,Excellent p...
# img_link             https://m.media-amazon.com/images/I/41fDdRtjfx...
# product_link         https://www.amazon.in/Noir-Aqua-Spanner-Purifi...
# rating_weighted                                                 4360.0
# sub_category                                  WaterPurifierAccessories
# main_category                                             Home&Kitchen
#
#                                                                   1461  \
# product_id                                                  B01M6453MB
# product_name         Prestige Delight PRWO Electric Rice Cooker (1 ...
# category             Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# discounted_price                                                2280.0
# actual_price                                                    3045.0
# discount_percentage                                               0.25
# rating                                                             4.1
# rating_count                                                    4118.0
# about_product                             230 Volts, 400 watts, 1 Year
# user_id              AFG5FM3NEMOL6BNFRV2NK5FNJCHQ,AGEINTRN6Z563RMLH...
# user_name            Manu Bhai,Naveenpittu,Evatira Sangma,JAGANNADH...
# review_id            R3DDL2UPKQ2CK9,R2SYYU1OATVIU5,R1VM993161IYRW,R...
# review_title         ok,everything was good couldn't return bcoz I ...
# review_content       ok,got everything as mentioned but the measuri...
# img_link             https://m.media-amazon.com/images/I/41gzDxk4+k...
# product_link         https://www.amazon.in/Prestige-Delight-PRWO-1-...
# rating_weighted                                                16883.8
# sub_category                                         Rice&PastaCookers
# main_category                                             Home&Kitchen
#
#                                                                   1462  \
# product_id                                                  B009P2LIL4
# product_name         Bajaj Majesty RX10 2000 Watts Heat Convector R...
# category             Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...
# discounted_price                                                2219.0
# actual_price                                                    3080.0
# discount_percentage                                               0.28
# rating                                                             3.6
# rating_count                                                     468.0
# about_product        International design and styling|Two heat sett...
# user_id              AGVPWCMAHYQWJOQKMUJN4DW3KM5Q,AF4Q3E66MY4SR7YQZ...
# user_name            Nehal Desai,Danish Parwez,Amazon Customer,Amaz...
# review_id            R1TLRJVW4STY5I,R2O455KRN493R1,R3Q5MVGBRIAS2G,R...
# review_title         very good,Work but front melt after 2 month,Go...
# review_content       plastic but cool body ,u have to find sturdy s...
# img_link             https://m.media-amazon.com/images/W/WEBP_40237...
# product_link         https://www.amazon.in/Bajaj-RX-10-2000-Watt-Co...
# rating_weighted                                                 1684.8
# sub_category                                            HeatConvectors
# main_category                                             Home&Kitchen
#
#                                                                   1463  \
# product_id                                                  B00J5DYCCA
# product_name         Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# category             Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...
# discounted_price                                                1399.0
# actual_price                                                    1890.0
# discount_percentage                                               0.26
# rating                                                             4.0
# rating_count                                                    8031.0
# about_product        Fan sweep area: 230 MM ; Noise level: (40 - 45...
# user_id              AF2JQCLSCY3QJATWUNNHUSVUPNQQ,AFDMLUXC5LS5RXDJS...
# user_name            Shubham Dubey,E.GURUBARAN,Mayank S.,eusuf khan...
# review_id            R39Q2Y79MM9SWK,R3079BG1NIH6MB,R29A31ZELTZNJM,R...
# review_title         Fan Speed is slow,Good quality,Good product,go...
# review_content       I have installed this in my kitchen working fi...
# img_link             https://m.media-amazon.com/images/W/WEBP_40237...
# product_link         https://www.amazon.in/Havells-Ventilair-230mm-...
# rating_weighted                                                32124.0
# sub_category                                               ExhaustFans
# main_category                                             Home&Kitchen
#
#                                                                   1464
# product_id                                                  B01486F4G6
# product_name         Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
# category             Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# discounted_price                                                2863.0
# actual_price                                                    3690.0
# discount_percentage                                               0.22
# rating                                                             4.3
# rating_count                                                    6987.0
# about_product        Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
# user_id              AFGW5PT3R6ZAVQR4Y5MWVAKBZAYA,AG7QNJ2SCS5VS5VYY...
# user_name            Rajib,Ajay B,Vikas Kahol,PARDEEP,Anindya Prama...
# review_id            R20RBRZ0WEUJT9,ROKIFK9R2ISSE,R30EEG2FNJSN5I,R2...
# review_title         Works perfect,Ok good product,Nice Product. Re...
# review_content       It does it job perfectly..only issue is temp c...
# img_link             https://m.media-amazon.com/images/W/WEBP_40237...
# product_link         https://www.amazon.in/Borosil-Jumbo-1000-Watt-...
# rating_weighted                                                30044.1
# sub_category                                            SandwichMakers
# main_category                                             Home&Kitchen
#
# [19 rows x 1462 columns]

# %% [markdown]
# # EDA and Data Visualizations

# %% [markdown]
# - First step: Analyze the distribution of products by category using a bar plot.
#
# - Second step: Analyze the distribution of customer ratings using a histogram.
#
# - Third step: Analyze the reviews by creating word clouds or frequency tables of the most common words used in the reviews.

# %%
import matplotlib.pyplot as plt

# Analyzing distribution of products by main category
main_category_counts = df['main_category'].value_counts()[:30] # Select only the top 30 main categories.
plt.bar(range(len(main_category_counts)), main_category_counts.values)
plt.ylabel('Number of Products')
plt.title('Distribution of Products by Main Category (Top 30)')
plt.xticks(range(len(main_category_counts)), '') # hide X-axis labels
plt.show()

# Top 30 main categories 
top_main_categories = pd.DataFrame({'Main Category': main_category_counts.index, 'Number of Products': main_category_counts.values})
print('Top 30 main categories:')
print(top_main_categories.to_string(index=False))
# Out:
# Top 30 main categories:
#         Main Category  Number of Products
#           Electronics                 526
# Computers&Accessories                 451
#          Home&Kitchen                 447
#        OfficeProducts                  31
#    MusicalInstruments                   2
#       HomeImprovement                   2
#            Toys&Games                   1
#         Car&Motorbike                   1
#   Health&PersonalCare                   1

# %% [markdown]
# Based on the results, we can gather the following insights:
#
# 🔍 The top three main categories are Electronics, Computers & Accessories, and Home & Kitchen. This shows that these categories are popular among customers.
#
# 🔍 The number of products in the other main categories is quite low, indicating that these categories are not as popular as the top three.
#
# 🔍 Office Products, Musical Instruments, Home Improvement, Toys & Games, Car & Motorbike, and Health & Personal Care have a very small number of products, which may suggest that these categories have less demand.
#
# 🔍 Overall, the data can help businesses understand the current market trends and identify potential opportunities for growth in specific categories.

# %%
# Analyzing distribution of products by last category
sub_category_counts = df['sub_category'].value_counts()[:30] # Select only the top 30 last categories.
plt.bar(range(len(sub_category_counts)), sub_category_counts.values)
plt.ylabel('Number of Products')
plt.title('Distribution of Products by Sub Category (Top 30)')
plt.xticks(range(len(sub_category_counts)), '') # hide X-axis labels
plt.show()

# Top 30 sub categories 
top_sub_categories = pd.DataFrame({'Sub Category': sub_category_counts.index, 'Number of Products': sub_category_counts.values})
print('Top 30 sub categories:')
print(top_sub_categories.to_string(index=False))
# Out:
# Top 30 sub categories:
#             Sub Category  Number of Products
#                USBCables                 231
#             SmartWatches                  76
#              Smartphones                  68
#         SmartTelevisions                  63
#                   In-Ear                  52
#           RemoteControls                  49
#            MixerGrinders                  27
#               HDMICables                  24
#                 DryIrons                  24
#                     Mice                  24
#      InstantWaterHeaters                  23
#              LintShavers                  22
#               FanHeaters                  20
#          ElectricHeaters                  20
#          ElectricKettles                  19
#             HandBlenders                  19
#      WirelessUSBAdapters                  18
#             WallChargers                  16
#                 Lapdesks                  14
#           LaundryBaskets                  13
#                  MicroSD                  13
#       Kettle&ToasterSets                  13
#               SteamIrons                  12
#      JuicerMixerGrinders                  12
#   WaterFilters&Purifiers                  12
#         ScreenProtectors                  12
#      StorageWaterHeaters                  12
#               PowerBanks                  12
#           SandwichMakers                  11
# WaterPurifierAccessories                  11

# %% [markdown]
# Based on the results, we can gather the following insights:
#
# 🔍 The top six subcategories are USB cables, smartwatches, smartphones, smart televisions, in-ear headphones, and remote controls. These are the most popular subcategories, and businesses could focus on providing products in these categories to attract customers.
#
# 🔍 Other popular subcategories include mixer grinders, HDMI cables, dry irons, mice, and instant water heaters. These subcategories may be less popular than the top six, but they still have a significant number of products, indicating that there is demand for them.
#
# 🔍 The data shows that there is a diverse range of subcategories in the top 30, including kitchen appliances, home electronics, and personal accessories. This highlights the importance of offering a variety of products to cater to different customer needs and preferences.
#
# 🔍 Overall, the data can help businesses identify the most popular subcategories and adjust their product offerings to meet customer demand. By focusing on these subcategories, businesses could increase their sales and improve their competitiveness in the market.

# %%
plt.hist(df['rating'])
plt.xlabel('Rating')
plt.ylabel('Number of Reviews')
plt.title('Distribution of Customer Ratings')
plt.show()

# Create table with values per cluster
bins = [0, 1, 2, 3, 4, 5] # Define bin edges
df['cluster'] = pd.cut(df['rating'], bins=bins, include_lowest=True, labels=['0-1', '1-2', '2-3', '3-4', '4-5'])
table = df['cluster'].value_counts().reset_index().rename(columns={'index': 'Cluster', 'cluster': 'Number of Reviews'})
print(table)
# Out:
#   Number of Reviews  count
# 0               4-5    928
# 1               3-4    525
# 2               2-3      8
# 3               1-2      1
# 4               0-1      0

# %% [markdown]
# 📊 The majority of customer ratings fall within the 3-4 and 4-5 range, with a total of 1453 reviews.
#
# 📈 There is a noticeable increase in the number of reviews in the 2-3 range compared to the lower 0-1 and 1-2 ranges.
#
# 👎 The lowest number of reviews is found in the 0-1 range, indicating that there may be room for improvement in terms of customer satisfaction.
#
# 🤔 Overall, the distribution of customer ratings suggests that most customers are satisfied with the products, but there may be opportunities for improvement to increase the number of positive ratings.

# %%
# Calculate the top main categories
top = df.groupby(['main_category'])['rating'].mean().sort_values(ascending=False).head(10).reset_index()

# Create a bar plot
plt.bar(top['main_category'], top['rating'])

# Add labels and title
plt.xlabel('main_category')
plt.ylabel('Rating')
plt.title('Top main_category by Rating')

# Rotate x-axis labels
plt.xticks(rotation=90)

# Show the plot
plt.show()
ranking = df.groupby('main_category')['rating'].mean().sort_values(ascending=False).reset_index()
print(ranking)
# Out:
#            main_category    rating
# 0         OfficeProducts  4.309677
# 1             Toys&Games  4.300000
# 2        HomeImprovement  4.250000
# 3  Computers&Accessories  4.155654
# 4            Electronics  4.081749
# 5           Home&Kitchen  4.040716
# 6    Health&PersonalCare  4.000000
# 7     MusicalInstruments  3.900000
# 8          Car&Motorbike  3.800000

# %% [markdown]
# 📊 Looking at this table, we can see the main categories ranked by their average rating. 💯
#
# 🏢 The main categories with the highest ratings are Office Products, Toys & Games, and Home Improvement, with ratings above 4.0. 👍 This suggests that customers are generally satisfied with the products offered in these categories.
#
# 💻 On the other hand, the main categories with lower ratings are Car & Motorbike, Musical Instruments, and Health & Personal Care, with ratings below 4.0. 🙁 This could indicate areas where improvements could be made to better meet customer expectations.
#
# 👨‍💻 Additionally, we can see that Computers & Accessories and Electronics have ratings above 4.0, which indicates that these categories are popular and well-liked by customers who purchase them. 🎉
#
# 👍 Overall, this table provides valuable insights into the performance of different main categories and can help businesses make informed decisions to improve their offerings and satisfy their customers.

# %%
# Calculate the top sub categories
top = df.groupby(['sub_category'])['rating'].mean().sort_values(ascending=False).head(10).reset_index()

# Create a bar plot
plt.bar(top['sub_category'], top['rating'])

# Add labels and title
plt.xlabel('sub_category')
plt.ylabel('Rating')
plt.title('Top sub_category by Rating')

# Rotate x-axis labels
plt.xticks(rotation=90)

# Show the plot
plt.show()
ranking = df.groupby('sub_category')['rating'].mean().sort_values(ascending=False).reset_index()
print(ranking)
# Out:
#                         sub_category  rating
# 0                            Tablets     4.6
# 1                               Film     4.5
# 2                             Memory     4.5
# 3    SmallApplianceParts&Accessories     4.5
# 4                   StreamingClients     4.5
# ..                               ...     ...
# 202                   InkjetPrinters     3.6
# 203                       PCHeadsets     3.5
# 204                        3DGlasses     3.5
# 205                       DustCovers     3.4
# 206                 ElectricGrinders     3.3
#
# [207 rows x 2 columns]

# %% [markdown]
# 📊 Looking at the table, we can see the top and bottom sub-categories in terms of customer ratings.
#
# 👍 It's great to see that the "Tablets" sub-category is at the top with a rating of 4.6, which indicates that customers are satisfied with their purchase.
#
# 📉 However, there are some sub-categories at the bottom, such as "DustCovers" and "ElectricGrinders", which have lower ratings, implying that customers are not very happy with these products.
#
# 💡 Insights like these can help businesses focus on improving the quality of their products and enhancing the overall customer experience. It's important to keep track of customer feedback to identify areas for improvement and continue to meet their needs and expectations.

# %%
from wordcloud import WordCloud

# 3.3 Analyze the reviews by creating word clouds or frequency tables of the most common words used in the reviews.
reviews_text = ' '.join(df['review_content'].dropna().values)
wordcloud = WordCloud(width=800, height=800, background_color='white', min_font_size=10).generate(reviews_text)
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
